# %%
import swimclub
# Out:
# Traceback (most recent call last):
#
#   File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import swimclub
#
#   File ~/Desktop/Hdfirst/learning/swimclub.py:25
#     min_secs, hundredths = f"{(average/100):.2f}.split(".")"
#                                                          ^
# SyntaxError: invalid syntax

# %%
fn = "Darius-13-100m-Fly.txt"

# %%
(swimmer, age, distance, stroke, *_) = swimclub.read_swim_date(fn)
title = swimmer + " (Under " + age + ") " + distance + " " + stroke
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 (swimmer, age, distance, stroke, *_) = swimclub.read_swim_date(fn)
#       2 title = swimmer + " (Under " + age + ") " + distance + " " + stroke
#
# AttributeError: module 'swimclub' has no attribute 'read_swim_date'

# %%
title
# Out:
# 'Darius (Under 13) 100m Fly'

# %%
html = "<!DOCTYPE html><html><head><title>" + title + "</title></head>"

# %%
html
# Out:
# '<!DOCTYPE html><html><head><title>Darius (Under 13) 100m Fly</title></head>'

# %%
html = "<!DOCTYPE html><html><head><title>" + title + "</title></head>"
html = html + "<body><h3>" + title + "</h3></body>"
html
# Out:
# '<!DOCTYPE html><html><head><title>Darius (Under 13) 100m Fly</title></head><body><h3>Darius (Under 13) 100m Fly</h3></body>'

# %%
title = f"{swimmer} (under {age}) {distance} {stroke}"
html = f"""
<!DOCTYPE html>
 <html>
  <head>
   <title> {title} </title>
  </head>
  <body>
   <h3> {title} </h3>
  </body>
 """

# %%
title
# Out:
# 'Darius (under 13) 100m Fly'

# %%
html
# Out:
# '\n<!DOCTYPE html>\n <html>\n  <head>\n   <title> Darius (under 13) 100m Fly </title>\n  </head>\n  <body>\n   <h3> Darius (under 13) 100m Fly </h3>\n  </body>\n '

# %%
print(html)
# Out:
# <!DOCTYPE html>
#  <html>
#   <head>
#    <title> Darius (under 13) 100m Fly </title>
#   </head>
#   <body>
#    <h3> Darius (under 13) 100m Fly </h3>
#   </body>

# %%
import swimclub

# %%
data = swimclub.read_swim_data(fn)

# %%
data
# Out:
# ('Darius',
#  '13',
#  '100m',
#  'Fly',
#  ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#  '1:26.58')

# %%
import swimclub

# %%
fn = "Darius-13-100m-Fly.txt"
*_, converts = swimclub.read_swim_data(fn)

# %%
converts
# Out:
# [8795, 8107, 9096, 8322, 8795, 8830]

# %%
_
# Out:
# ['Darius',
#  '13',
#  '100m',
#  'Fly',
#  ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#  '1:26.58']

# %%
import hfpy_utils

for n in converts:
    print(n, "->", hfpy_utils.convert2range(n, 0, max(converts), 0, 400))
# Out:
# 8795 -> 386.76
# 8107 -> 356.51
# 9096 -> 400.0
# 8322 -> 365.96
# 8795 -> 386.76
# 8830 -> 388.3

# %%
times, average, converts, *_ = swimclub.read_swim_data(fn)

# %%
from_max = max(converts)

# %%
import hfpy_utils
svgs = ""

# %%
import swimclub
import hfpy_utils
fn = "Darius-13-100m-Fly.txt"
swimmer, age, distance, stroke, times, average, converts = swimclub.read_swim_data(fn)
title = f"{swimmer} (under {age}) {distance} {stroke}"
html = f"""
<!DOCTYPE html>
 <html>
  <head>
   <title> {title} </title>
  </head>
  <body>
   <h3> {title} </h3>
  </body>
 """



svgs = ""
times.reverse()
converts.reverse()
from_max = max(converts)
for n, t in enumerate(times):
    bar_width = hfpy_utils.convert2range(converts[n], 0, from_max, 0, 350)
    svgs = svgs + f"""
    <svg height="30" width="400">
    <rect height="30" width="{bar_width}" style="fill:rgb(0,0,255);" />
    </svg>{t}<br />
    """

# %%
print(svgs)
# Out:
#     <svg height="30" width="400">
#     <rect height="30" width="339.76" style="fill:rgb(0,0,255);" />
#     </svg>1:28.30<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="338.42" style="fill:rgb(0,0,255);" />
#     </svg>1:27.95<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="320.22" style="fill:rgb(0,0,255);" />
#     </svg>1:23.22<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="350.0" style="fill:rgb(0,0,255);" />
#     </svg>1:30.96<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="311.94" style="fill:rgb(0,0,255);" />
#     </svg>1:21.07<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="338.42" style="fill:rgb(0,0,255);" />
#     </svg>1:27.95<br />

# %%
footer = f"""
        <p>{average}</p>
    </body>
</html>
"""

# %%
page = html + svgs + footer

# %%
page
# Out:
# '\n<!DOCTYPE html>\n <html>\n  <head>\n   <title> Darius (under 13) 100m Fly </title>\n  </head>\n  <body>\n   <h3> Darius (under 13) 100m Fly </h3>\n  </body>\n \n    <svg height="30" width="400">\n    <rect height="30" width="339.76" style="fill:rgb(0,0,255);" />\n    </svg>1:28.30<br />\n    \n    <svg height="30" width="400">\n    <rect height="30" width="338.42" style="fill:rgb(0,0,255);" />\n    </svg>1:27.95<br />\n    \n    <svg height="30" width="400">\n    <rect height="30" width="320.22" style="fill:rgb(0,0,255);" />\n    </svg>1:23.22<br />\n    \n    <svg height="30" width="400">\n    <rect height="30" width="350.0" style="fill:rgb(0,0,255);" />\n    </svg>1:30.96<br />\n    \n    <svg height="30" width="400">\n    <rect height="30" width="311.94" style="fill:rgb(0,0,255);" />\n    </svg>1:21.07<br />\n    \n    <svg height="30" width="400">\n    <rect height="30" width="338.42" style="fill:rgb(0,0,255);" />\n    </svg>1:27.95<br />\n    \n        <p>1:26.58</p>\n    </b
# ...

# %%
print(page)
# Out:
# <!DOCTYPE html>
#  <html>
#   <head>
#    <title> Darius (under 13) 100m Fly </title>
#   </head>
#   <body>
#    <h3> Darius (under 13) 100m Fly </h3>
#   </body>
#
#     <svg height="30" width="400">
#     <rect height="30" width="339.76" style="fill:rgb(0,0,255);" />
#     </svg>1:28.30<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="338.42" style="fill:rgb(0,0,255);" />
#     </svg>1:27.95<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="320.22" style="fill:rgb(0,0,255);" />
#     </svg>1:23.22<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="350.0" style="fill:rgb(0,0,255);" />
#     </svg>1:30.96<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="311.94" style="fill:rgb(0,0,255);" />
#     </svg>1:21.07<br />
#
#     <svg height="30" width="400">
#     <rect height="30" width="338.42" style="fill:rgb(0,0,255);" />
#     </svg>1:27.95<br />
#
#         <p>1:26.58</p>
# ...

# %%
with open("test.txt", "w") as tf:
    print("This is a test", file=tf)

# %%
filen = fn.removesuffix(".txt")

# %%
save_to = f"charts/{filen}.html"

# %%
save_to
# Out:
# 'charts/Darius-13-100m-Fly.html'

# %%
with open(save_to, "w") as ft:
    print(page, file=ft)

# %%
import os

# %%
import webbrowser

# %%
webbrowser.open("file://" + os.path.realpath(save_to))
# Out:
# True

# %%
import os
import swimclub
import webbrowser

swimclub.produce_bar_chart("Darius-13-100m-Fly.txt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 import swimclub
#       3 import webbrowser
# ----> 5 swimclub.produce_bar_chart("Darius-13-100m-Fly.txt")
#
# File ~/Desktop/Hdfirst/learning/swimclub.py:37, in produce_bar_chart(fn)
#      32 def produce_bar_chart(fn):
#      33     """Given the name of a swimmer's file, produce a HTML/SVG-based bar chart.
#      34
#      35     Save the chart to the CHARTS folder. Return the path to the bar chart file.
#      36     """
# ---> 37     swimmer, age, distance, stroke, times, average, converts = read_swim_data(fn)
#      38     from_max = max(converts)
#      39     times.reverse()
#
# File ~/Desktop/Hdfirst/learning/swimclub.py:25, in read_swim_data(filename)
#      22     converts.append((int(minutes)*60*100) + (int(seconds)*100) + (int(hundredths)))
#      24 average = statistics.mean(converts)
# ...

# %%
chart = swimclub.product_bar_chart("Darius-13-100m-Fly.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# True

# %%
chart = swimclub.product_bar_chart("Dave-17-100m-Free.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# True

# %%
chart = swimclub.product_bar_chart("Lizzie-14-100m-Back.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# True

# %%
chart = swimclub.produce_bar_chart("Lizzie-14-100m-Back.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 chart = swimclub.produce_bar_chart("Lizzie-14-100m-Back.txt")
#       2 webbrowser.open("file://" + os.path.realpath(chart))
#
# NameError: name 'swimclub' is not defined

# %%
import statistics
FOLDER = "swimdata/"
import hfpy_utils
CHARTS = "charts/"

def read_swim_data(filename):
    #process swimmer's details from each file and return the values
    swimmer, age, distance, stroke = filename.removesuffix(".txt").split("-")
    
    with open(FOLDER + filename) as file:
        lines = file.readlines()
        times = lines[0].strip().split(",")

    converts = []
    for t in times:
        if ":" in t:
            minutes, rest = t.split(":")
            seconds, hundredths = rest.split(".")
        else:
            minutes = 0
            seconds, hundredths = t.split(".")
        converts.append((int(minutes)*60*100) + (int(seconds)*100) + (int(hundredths)))

    average = statistics.mean(converts)
    min_secs, hundredths = f"{(average/100):.2f}".split('.')
    minutes = int(min_secs) // 60
    seconds = int(min_secs) - (minutes*60)
    average = f"{minutes}:{seconds:0>2}.{hundredths}"

    return swimmer, age, distance, stroke, times, average, converts

# %%
swimmer, age, distance, stroke, times, average, converts = read_swim_data("Lizzie-14-100m-Back.txt")

# %%
average
# Out:
# '1:29.20'

# %%
import os
import swimclub
import webbrowser

swimclub.produce_bar_chart("Darius-13-100m-Fly.txt")

chart = swimclub.product_bar_chart("Darius-13-100m-Fly.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       3 import webbrowser
#       5 swimclub.produce_bar_chart("Darius-13-100m-Fly.txt")
# ----> 7 chart = swimclub.product_bar_chart("Darius-13-100m-Fly.txt")
#       8 webbrowser.open("file://" + os.path.realpath(chart))
#
# AttributeError: module 'swimclub' has no attribute 'product_bar_chart'

# %%
import os
import swimclub
import webbrowser


chart = swimclub.produce_bar_chart("Darius-13-100m-Fly.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# True

# %%
chart = swimclub.produce_bar_chart("Lizzie-14-100m-Back.txt")
webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# True
